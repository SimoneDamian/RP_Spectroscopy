# %% [markdown]
# # Controller for the locking of the laser

# %%
# %load_ext autoreload
# %autoreload 2

from GettingStarted_lib.Interface import Interface
from GettingStarted_lib.LaserLockingController import LaserLockingController
import pprint
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Creating the interface:
#
# It contains everything is needed for the comunications with the linien server in the RedPitaya.
# - connection to the board;
# - Initialization of the parameters;
# - Parameters modification.

# %%
RP_Interface = Interface()
RP_Locking_Controller = LaserLockingController(RP_Interface)
# Out:
# 2026-02-26 18:21:40 - Interface - INFO - Configuration loaded from /home/bec3/Desktop/Simone_Damian/RP_Spectroscopy/GettingStarted_lib/connect_config.yaml:
#
# 2026-02-26 18:21:40 - Interface - INFO - Attempting connection via RedPitaya_K address (192.168.1.159:18862)
# linien_client.connection       INFO     Try to connect to 192.168.1.159:18862
# linien_client.connection       DEBUG    Sent authentication hash
# linien_client.connection       INFO     Connection established!
# 2026-02-26 18:21:43 - Interface - INFO - Connected to device via RedPitaya_K address
# 2026-02-26 18:21:44 - DataHandler - INFO - All reference lines loaded successfully.
# 2026-02-26 18:21:44 - LaserLockingController - INFO - LaserLockController initialized successfully.

# %%
pprint.pprint(vars(RP_Interface))

RP_Interface.client.parameters.check_for_changed_parameters()
params = RP_Interface.client.parameters
for name, param in vars(params).items():
    # Only pick those attributes that are actual Linien parameters
    if hasattr(param, "value"):
        print(f"{name}: {param.value}")
# Out:
# {'DEVICES': {'RedPitaya_K': {'ip': '192.168.1.159',
#                              'linien_port': 18862,
#                              'ssh_port': 22}},
#  'PASSWORD': 'root',
#  'USERNAME': 'root',
#  'client': <linien_client.connection.LinienClient object at 0x7078b400df30>,
#  'device': Device(key='dhmtcalcvf',
#                   name='',
#                   host='192.168.1.159',
#                   port=18862,
#                   username='root',
#                   password='root',
#                   parameters={}),
#  'logger': <Logger Interface (INFO)>,
#  'readable_params': {'control_signal_history': <GettingStarted_lib.Interface.ReadableParameter object at 0x7078b2ffea40>,
#                      'monitor_signal_history': <GettingStarted_lib.Interface.ReadableParameter object at 0x7078b2ffc1f0>,
#                      'sweep_signal': <GettingStarted_lib.Interface.ReadableParameter object at 0x7078b2ffdc00>},
#  'writeable_params': {'big_offset': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2ffece0>,
#                       'channel_mixing': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b315b700>,
#                       'control_channel': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2ffec20>,
#                       'control_history_length': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2ffdba0>,
#                       'demodulation_multiplier_a': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b315bf40>,
#                       'demodulation_multiplier_b': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b300b5b0>,
#                       'dual_channel': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b315beb0>,
#                       'filter_1_enabled_a': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b315a8f0>,
#                       'filter_1_enabled_b': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b315bf10>,
#                       'filter_1_frequency': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2ffdd20>,
#                       'filter_1_type_a': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b3763160>,
#                       'filter_1_type_b': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2fff370>,
#                       'filter_2_enabled_a': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b3763700>,
#                       'filter_2_enabled_b': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2fff490>,
#                       'filter_2_frequency': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2ffdb70>,
#                       'filter_2_type_a': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b315b6d0>,
#                       'filter_2_type_b': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2fffb20>,
#                       'filter_automatic_a': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b315b1c0>,
#                       'filter_automatic_b': <GettingStarted_lib.Interface.WriteableParameter object at 0x7079045f3a90>,
#                       'invert_a': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b31590f0>,
#                       'invert_b': <GettingStarted_lib.Interface.WriteableParameter object at 0x7079045f3970>,
#                       'modulation_amplitude': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2ffecb0>,
#                       'modulation_channel': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2fff910>,
#                       'modulation_frequency': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2fff3a0>,
#                       'offset_a': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b315a890>,
#                       'offset_b': <GettingStarted_lib.Interface.WriteableParameter object at 0x7079045f3880>,
#                       'phase': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2ffe9e0>,
#                       'pid_d': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2ffc100>,
#                       'pid_i': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2ffc490>,
#                       'pid_on_slow_enabled': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2ffda80>,
#                       'pid_p': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2ffdbd0>,
#                       'pid_slow_strength': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2ffc1c0>,
#                       'polarity_analog_out0': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2fff520>,
#                       'polarity_fast_out1': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2ffec80>,
#                       'polarity_fast_out2': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2ffead0>,
#                       'slow_control_channel': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2ffeaa0>,
#                       'small_offset': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2fff400>,
#                       'sweep_amplitude': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2ffdc30>,
#                       'sweep_center': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2ffeb90>,
#                       'sweep_channel': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2ffc070>,
#                       'sweep_speed': <GettingStarted_lib.Interface.WriteableParameter object at 0x7078b2ffea70>}}

# %%
RP_Interface.set_value('big_offset', 0.97)

# %%
RP_Interface.plot_sweep()

# %%
RP_Interface.adjust_vertical_offset()
# Out:
# Actual offset_a: 0.0
# New offset_a set to: 0.0

# %%
RP_Interface.start_sweep()
RP_Locking_Controller.start_manual_locking()
# Out:
# checking lock status...
# checking lock status...
# checking lock status...
# checking lock status...
# checking lock status...
# Locking the laser worked! \o/
# 2025-12-15 15:57:58 - UnlockEventsLogger - INFO - Laser locked at time: 2025-12-15 15:57:58

# %%
RP_Locking_Controller.start_locking_monitor()
# Out:
# Laser lost locking
# Trying to center the line looking at the slow control signal...

# %%
RP_Interface.start_sweep()

# %%
RP_Locking_Controller.scan(0.9, 1.0, 10)
# Out:
# 2026-02-25 14:53:57 - LaserLockingController - INFO - Starting scan from 0.9V to 1.0V with 10 points.
# Scanning at voltage 1.000V (10/10) [##########] (16.28s) Done!
# 2026-02-25 14:54:13 - LaserLockingController - INFO - Scan completed successfully.

# %%
RP_Locking_Controller.save_reference_line(key = 'K_D2', V_scan = 0.944, start_voltage=-0.35, stop_voltage=0.35, V_lock_start = 0.15, V_lock_end = 0.3, offset=0)
# Out:
# 2026-01-29 13:47:02 - LaserLockingController - INFO - Saving reference line with key K_D2.
# 2026-01-29 13:47:02 - DataHandler - INFO - Saved reference line: REFERENCE_LINE_K_D2.npy
# 2026-01-29 13:47:02 - DataHandler - INFO - All reference lines loaded successfully.
# 2026-01-29 13:47:02 - LaserLockingController - INFO - Reference line K_D2 saved successfully.

# %%
RP_Locking_Controller.find_reference_lines(start_voltage = 0.9, stop_voltage = 1.0, num_points = 10)
# Out:
# 2026-01-20 14:39:05 - LaserLockingController - INFO - Finding reference lines.
# Scanning at voltage 1.000V (10/10) [##########] (17.24s) Done!
# 0.0
# 2026-01-20 14:39:23 - LaserLockingController - INFO - Reference lines found successfully.

# %%
RP_Interface.check_for_changed_parameters()
RP_Interface.get_remote_value('offset_a')
# Out:
# 0.0

# %%
RP_Locking_Controller.set_debug_mode()

# %%
RP_Locking_Controller.center_and_lock_v1('LINE_K_D2')
# Out:
# 2026-01-20 10:12:19 - LaserLockingController - DEBUG - Frequency stable enough
# 2026-01-20 10:12:19 - LaserLockingController - INFO - Line LINE_K_D2 is centered at offset 1.01.
# 2026-01-20 10:12:19 - LaserLockingController - DEBUG - Starting autolock between indices 1197 and 1453.
# 2026-01-20 10:12:19 - LaserLockingController - DEBUG - First 10 values of sweep signal raw: [15. 17. 17. 18. 18. 18. 18. 18. 18. 18.]
# Started autolock
# checking lock status...
# checking lock status...
# checking lock status...
# checking lock status...
# checking lock status...
# checking lock status...
# checking lock status...
# checking lock status...
# checking lock status...
# checking lock status...
# checking lock status...
# 2026-01-20 10:12:30 - LaserLockingController - INFO - Locking the laser failed :(
# 2026-01-20 10:12:30 - LaserLockingController - INFO - Exiting centering and locking procedure.

# %%
RP_Locking_Controller.set_debug_mode()

# %%
RP_Locking_Controller.unset_debug_mode()

# %%
RP_Locking_Controller.automatic_lock_relock('LINE_K_D2')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 RP_Locking_Controller.automatic_lock_relock('LINE_K_D2')
#
# File ~/Desktop/Simone_Damian/Serafini/GettingStarted_lib/LaserLockingController.py:721, in LaserLockingController.automatic_lock_relock(self, line_name, relock)
#     719 else:
#     720     while True:
# --> 721         self.start_locking_monitor()
#     722         self.find_reference_lines(self.hardware_interface.get_remote_value('big_offset') - 0.02, self.hardware_interface.get_remote_value('big_offset') + 0.02, 6)
#     723         try:
#
# File ~/Desktop/Simone_Damian/Serafini/GettingStarted_lib/LaserLockingController.py:176, in LaserLockingController.start_locking_monitor(self)
#     173     self.hardware_interface.plot_sweep()
#     174     break
# --> 176 sleep(5)
#
# KeyboardInterrupt:

# %%
RP_Interface.start_sweep()

# %% [markdown]
# ## Analog out test

# %%
RP_Interface.check_for_changed_parameters()
RP_Interface.get_remote_value('offset_a')
RP_Interface.get_remote_value('big_offset')
# Out:
# 0.0

# %%
RP_Interface.set_value('big_offset', 0.93)

# %%
RP_Interface.set_value('sweep_amplitude', 0.7)

# %%
RP_Interface.plot_sweep()
